# %% [markdown]
# # Pose Correction — Single Frame (MLP)
#
# This notebook trains a simple **MLP baseline** to predict per-joint displacement from a **single pose frame**.
#
# - **Dataset**: `Data/output_displacement_single_frame/training_data_displacement_per_frame.npz`
# - **Input**: flattened pose (`12 × C`, with `C=2` here) + workout class one-hot (`17`)
# - **Target**: flattened displacement (`12 × C`)
# - **Training loss**: masked **Huber** on **displaced joints only** (joints where \(\|y_{\text{true}}\|_2 > 10^{-6}\)); non-displaced joints do not contribute to the loss.
#
# ## Why does this converge so fast vs `AI/pose_correction/*`?
#
# Compared to the sequence notebooks in `AI/pose_correction/`, this setup can *look* dramatically better for a few reasons:
#
# - The dataset is **single-frame** (`sequence_length = 1`), so the model doesn’t need to learn temporal aggregation.
# - The generator applies displacement with probability \(p=0.85\), so a meaningful portion of rows can be **near-zero targets** (easy loss / fast convergence).
# - The split is at the **frame-row level** (not video-level), so frames from the same video can land in both train/test; this can **inflate test metrics**. A true apples-to-apples comparison needs a **video-level split** (requires row→video metadata).

# %% [markdown]
# ## How to read the results (important)
#
# The dataset has these properties that make the metrics easy to misread:
#
# - **Tiny target magnitude**: each displaced joint coord is `~Uniform(-0.1, +0.1)`.
# - **Per row, only 0–3 of 12 joints are displaced** (≈36% of rows are *fully* clean).
# - **The unmasked global MAE is dominated by the many zero targets**, so a "predict 0 everywhere" baseline already gives a very small unmasked MAE. That's the trap that makes it look like nothing is converging.
#
# The right number to track is the **masked MAE on displaced joints**, with these reference values:
#
# | Quantity | Value |
# |---|---|
# | Predict-zero masked-MAE (baseline) | **≈ 0.100** |
# | MLP after a few epochs | clearly drops below 0.10, towards ~0.03–0.05 |
#
# You should see `val_masked_displaced_joint_mae` go from ~0.10 to ~0.04 within ~50 epochs. If it stays at ~0.10, the model has collapsed to predicting zero (i.e., it has *not* learned).
#
# Why the qualitative arrow plots can *look* random:
#
# - Predicted arrows appear on **all 12 joints** (the model puts a small magnitude on every joint), while ground-truth arrows appear on only 1–3.
# - True arrows are very short (max length ≈ 0.1 in normalized image coords) so they are hard to see next to the skeleton.

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

np.random.seed(42)
tf.random.set_seed(42)

print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# TensorFlow version: 2.21.0
# Keras version: 3.14.0

# %%
data_path = Path("../../Data/output_displacement_single_frame/training_data_displacement_per_frame.npz")
metadata_path = Path("../../Data/output_displacement_single_frame/training_data_displacement_per_frame_metadata.json")

with open(metadata_path, "r") as f:
    metadata = json.load(f)

data = np.load(data_path, allow_pickle=True)
X = data["X"].astype(np.float32)
y = data["y"].astype(np.float32)

print("Dataset metadata:")
print(f"  n_samples: {metadata['n_samples']}")
print(f"  n_landmarks: {metadata['n_landmarks']}")
print(f"  n_coords: {metadata['n_coords']}")
print(f"  X_shape: {metadata['X_shape']}")
print(f"  y_shape: {metadata['y_shape']}")
print(f"  X_pose_flat_dim: {metadata['X_pose_flat_dim']}")
print(f"  X_class_dim: {metadata['X_class_dim']}")

print(f"\n.npz keys: {list(data.keys())}")
print(f"X: {X.shape}, y: {y.shape}")
# Out:
# Dataset metadata:
#   n_samples: 188661
#   n_landmarks: 12
#   n_coords: 2
#   X_shape: [188661, 29]
#   y_shape: [188661, 24]
#   X_pose_flat_dim: 24
#   X_class_dim: 5
#
# .npz keys: ['X', 'y', 'y_class', 'y_class_onehot', 'y_class_raw', 'class_names', 'n_landmarks', 'n_coords', 'sequence_length']
# X: (188661, 29), y: (188661, 24)

# %%
# --------
# Sanity tests + dataset visuals
# --------

y_class = data["y_class"].astype(np.int64)
y_class_onehot = data["y_class_onehot"].astype(np.float32)
class_names = [str(x) for x in data["class_names"].tolist()]

assert X.ndim == 2 and y.ndim == 2
assert X.shape[0] == y.shape[0]
assert y_class.shape[0] == X.shape[0]
assert y_class_onehot.shape == (X.shape[0], len(class_names))
assert np.all((y_class_onehot.sum(axis=1) == 1.0) | (y_class_onehot.sum(axis=1) == 0.0))

print("Basic checks:")
print("  any NaNs in X?", bool(np.isnan(X).any()))
print("  any NaNs in y?", bool(np.isnan(y).any()))
print("  class_names:", len(class_names))

# How much of the dataset is 'no displacement'? (y ~= 0)
y_norm = np.linalg.norm(y, axis=1)
print("\nTarget magnitude stats (L2 over 24 dims):")
print("  mean:", float(np.mean(y_norm)))
print("  p50:", float(np.percentile(y_norm, 50)))
print("  p90:", float(np.percentile(y_norm, 90)))
print("  frac(|y|<1e-6):", float(np.mean(y_norm < 1e-6)))
print("  frac(|y|<1e-3):", float(np.mean(y_norm < 1e-3)))

plt.figure(figsize=(7, 4))
plt.hist(y_norm, bins=80)
plt.title("Target displacement magnitude (L2) histogram")
plt.xlabel("||y||")
plt.ylabel("count")
plt.tight_layout()
plt.show()

# Per-dimension variance (if some dims are near-constant)
y_std = np.std(y, axis=0)
plt.figure(figsize=(10, 3))
plt.plot(y_std)
plt.title("Per-dimension std of y")
plt.xlabel("y dimension")
plt.ylabel("std")
plt.tight_layout()
plt.show()
# Out:
# Basic checks:
#   any NaNs in X? False
#   any NaNs in y? False
#   class_names: 5
#
# Target magnitude stats (L2 over 24 dims):
#   mean: 0.09270516782999039
#   p50: 0.10200747102499008
#   p90: 0.15371906757354736
#   frac(|y|<1e-6): 0.14976068185793567
#   frac(|y|<1e-3): 0.14978188390817393

# %%
pose_dim = int(metadata["X_pose_flat_dim"])
class_dim = int(metadata["X_class_dim"])
y_dim = int(metadata["y_final_disp_flat_dim"])

assert X.shape[1] == pose_dim + class_dim
assert y.shape[1] == y_dim

# NOTE: The dataset rows are per-frame. A truly fair split is by *video*,
# but the row->video mapping is not present in the .npz by default.
# We at least split stratified by workout class to avoid class imbalance.

def stratified_split_indices(y_class_idx: np.ndarray, *, seed: int = 42, train_frac=0.8, val_frac=0.1):
    rng = np.random.default_rng(seed)
    train, val, test = [], [], []
    for c in np.unique(y_class_idx):
        c_idx = np.where(y_class_idx == c)[0]
        rng.shuffle(c_idx)
        n = len(c_idx)
        n_train = int(train_frac * n)
        n_val = int(val_frac * n)
        train.append(c_idx[:n_train])
        val.append(c_idx[n_train : n_train + n_val])
        test.append(c_idx[n_train + n_val :])
    return np.concatenate(train), np.concatenate(val), np.concatenate(test)

train_idx, val_idx, test_idx = stratified_split_indices(y_class, seed=42)

# Shuffle within each split (stable shapes, nicer batching)
rng = np.random.default_rng(42)
rng.shuffle(train_idx)
rng.shuffle(val_idx)
rng.shuffle(test_idx)

X_train, y_train = X[train_idx], y[train_idx]
X_val, y_val = X[val_idx], y[val_idx]
X_test, y_test = X[test_idx], y[test_idx]

print("Split sizes:")
print(f"  train: {X_train.shape}")
print(f"  val:   {X_val.shape}")
print(f"  test:  {X_test.shape}")

# Show class distribution per split
for name, idxs in [("train", train_idx), ("val", val_idx), ("test", test_idx)]:
    counts = np.bincount(y_class[idxs], minlength=len(class_names))
    top = np.argsort(-counts)[:5]
    print(f"\n{name} top-5 classes:")
    for k in top:
        if counts[k] > 0:
            print(f"  {class_names[k]:<22} {int(counts[k])}")
# Out:
# Split sizes:
#   train: (150927, 29)
#   val:   (18864, 29)
#   test:  (18870, 29)
#
# train top-5 classes:
#   pull_ups               47734
#   bicep_curls            33616
#   lateral_raises         23939
#   push_ups               23842
#   deadlift               21796
#
# val top-5 classes:
#   pull_ups               5966
#   bicep_curls            4202
#   lateral_raises         2992
#   push_ups               2980
#   deadlift               2724
#
# test top-5 classes:
#   pull_ups               5968
#   bicep_curls            4203
#   lateral_raises         2993
#   push_ups               2981
#   deadlift               2725

# %%
# --------
# Non-zero target ratio (and optional sample weighting)
# --------

# Many rows are "clean" (no displacement). If we weight them equally,
# the model can look like it predicts ~0 everywhere.

eps = 1e-6
train_norm = np.linalg.norm(y_train, axis=1)
val_norm = np.linalg.norm(y_val, axis=1)
test_norm = np.linalg.norm(y_test, axis=1)

print("Non-zero target ratios:")
print(f"  train frac(|y|<{eps}): {float(np.mean(train_norm < eps)):.3f}")
print(f"  val   frac(|y|<{eps}): {float(np.mean(val_norm < eps)):.3f}")
print(f"  test  frac(|y|<{eps}): {float(np.mean(test_norm < eps)):.3f}")

# Weight non-zero rows higher so we learn the displacement mapping.
# Tune this if you want (e.g. 1, 3, 5, 10).
nonzero_weight = 5.0
sample_weight_train = np.where(train_norm < eps, 1.0, nonzero_weight).astype(np.float32)
sample_weight_val = np.where(val_norm < eps, 1.0, nonzero_weight).astype(np.float32)

print("Sample weights:")
print("  train mean weight:", float(sample_weight_train.mean()))
print("  val   mean weight:", float(sample_weight_val.mean()))
# Out:
# Non-zero target ratios:
#   train frac(|y|<1e-06): 0.150
#   val   frac(|y|<1e-06): 0.150
#   test  frac(|y|<1e-06): 0.150
# Sample weights:
#   train mean weight: 4.401326656341553
#   val   mean weight: 4.398430824279785

# %%
norm = layers.Normalization(axis=-1)
norm.adapt(X_train)

# Loss / metrics: only joints with non-zero *ground-truth* displacement (per sample).
_N_J = int(metadata["n_landmarks"])
_N_C = int(metadata["n_coords"])
_HUBER_DELTA = 0.05
_DISP_EPS = 1e-6


def masked_displaced_joint_huber(y_true, y_pred):
    yt = tf.reshape(y_true, (-1, _N_J, _N_C))
    yp = tf.reshape(y_pred, (-1, _N_J, _N_C))
    err = yt - yp
    joint_norm_true = tf.linalg.norm(yt, axis=-1)
    mask = tf.cast(joint_norm_true > _DISP_EPS, tf.float32)
    mask_w = tf.expand_dims(mask, -1)
    abs_err = tf.abs(err)
    quad = 0.5 * tf.square(err)
    lin = _HUBER_DELTA * (abs_err - 0.5 * _HUBER_DELTA)
    huber = tf.where(abs_err <= _HUBER_DELTA, quad, lin)
    masked = huber * mask_w
    denom = tf.reduce_sum(mask_w) + 1e-8
    return tf.reduce_sum(masked) / denom


def masked_displaced_joint_mae(y_true, y_pred):
    yt = tf.reshape(y_true, (-1, _N_J, _N_C))
    yp = tf.reshape(y_pred, (-1, _N_J, _N_C))
    joint_norm_true = tf.linalg.norm(yt, axis=-1)
    mask = tf.cast(joint_norm_true > _DISP_EPS, tf.float32)
    mask_w = tf.expand_dims(mask, -1)
    ae = tf.abs(yt - yp) * mask_w
    denom = tf.reduce_sum(mask_w) + 1e-8
    return tf.reduce_sum(ae) / denom


def build_mlp(input_dim: int, output_dim: int) -> keras.Model:
    inp = keras.Input(shape=(input_dim,), name="X")
    x = norm(inp)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Dense(128, activation="relu")(x)
    out = layers.Dense(output_dim, name="y_pred")(x)
    x = layers.Dense(128, activation="relu")(x)
    out = layers.Dense(output_dim, name="y_pred")(x)
    return keras.Model(inp, out)

model = build_mlp(input_dim=X.shape[1], output_dim=y.shape[1])
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=masked_displaced_joint_huber,
    metrics=[masked_displaced_joint_mae],
)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X (InputLayer)                  │ (None, 29)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization (Normalization)   │ (None, 29)             │            59 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        15,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ y_pred (Dense)                  │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 461,907 (1.76 MB)
#  Trainable params: 461,848 (1.76 MB)
#  Non-trainable params: 59 (240.00 B)

# %%
# --------
# Baselines (to ensure we're solving the same regression problem)
# --------

def mae_global(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    return float(np.mean(np.abs(y_true - y_pred)))


def mae_masked_displaced(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    yt = y_true.reshape((-1, _N_J, _N_C))
    yp = y_pred.reshape((-1, _N_J, _N_C))
    mask = (np.linalg.norm(yt, axis=-1) > _DISP_EPS)[..., None]
    ae = np.abs(yt - yp) * mask
    return float(ae.sum() / max(mask.sum(), 1.0))


zero_pred = np.zeros_like(y_test)
mean_pred = np.repeat(np.mean(y_train, axis=0, keepdims=True), repeats=y_test.shape[0], axis=0)

print("Baseline: predict all zeros")
print(f"  unmasked MAE         : {mae_global(y_test, zero_pred):.6f}  (dominated by zero targets, not informative)")
print(f"  masked MAE (disp jt) : {mae_masked_displaced(y_test, zero_pred):.6f}  <- track THIS")

print("\nBaseline: predict train mean")
print(f"  unmasked MAE         : {mae_global(y_test, mean_pred):.6f}")
print(f"  masked MAE (disp jt) : {mae_masked_displaced(y_test, mean_pred):.6f}")
# Out:
# Baseline: predict all zeros
#   unmasked MAE         : 0.007052  (dominated by zero targets, not informative)
#   masked MAE (disp jt) : 0.099754  <- track THIS
#
# Baseline: predict train mean
#   unmasked MAE         : 0.007099
#   masked MAE (disp jt) : 0.099753

# %%
callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=25, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=15, min_lr=1e-6),
]

history = model.fit(
    X_train,
    y_train,
    sample_weight=sample_weight_train,
    validation_data=(X_val, y_val, sample_weight_val),
    epochs=250,
    batch_size=256,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0076 - masked_displaced_joint_mae: 0.0694 - val_loss: 0.0033 - val_masked_displaced_joint_mae: 0.0425 - learning_rate: 0.0010
# Epoch 2/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0034 - masked_displaced_joint_mae: 0.0435 - val_loss: 0.0024 - val_masked_displaced_joint_mae: 0.0357 - learning_rate: 0.0010
# Epoch 3/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0029 - masked_displaced_joint_mae: 0.0397 - val_loss: 0.0022 - val_masked_displaced_joint_mae: 0.0337 - learning_rate: 0.0010
# Epoch 4/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0027 - masked_displaced_joint_mae: 0.0380 - val_loss: 0.0021 - val_masked_displaced_joint_mae: 0.0330 - learning_rate: 0.0010
# Epoch 5/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0026 - masked_displaced_joint_mae: 0.0370 - val_loss: 0.0021 - val_masked_displaced_joint_mae: 0.0325 - learning_rate: 0.0010
# Epoch 6/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0025 - masked_displaced_joint_mae: 0.0363 - val_loss: 0.0020 - val_masked_displaced_joint_mae: 0.0320 - learning_rate: 0.0010
# Epoch 7/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024 - masked_displaced_joint_mae: 0.0357 - val_loss: 0.0020 - val_masked_displaced_joint_mae: 0.0317 - learning_rate: 0.0010
# Epoch 8/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023 - masked_displaced_joint_mae: 0.0351 - val_loss: 0.0019 - val_masked_displaced_joint_mae: 0.0315 - learning_rate: 0.0010
# Epoch 9/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0023 - masked_displaced_joint_mae: 0.0347 - val_loss: 0.0019 - val_masked_displaced_joint_mae: 0.0308 - learning_rate: 0.0010
# Epoch 10/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0022 - masked_displaced_joint_mae: 0.0344 - val_loss: 0.0019 - val_masked_displaced_joint_mae: 0.0308 - learning_rate: 0.0010
# Epoch 11/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0022 - masked_displaced_joint_mae: 0.0340 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0303 - learning_rate: 0.0010
# Epoch 12/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0022 - masked_displaced_joint_mae: 0.0338 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0304 - learning_rate: 0.0010
# Epoch 13/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0021 - masked_displaced_joint_mae: 0.0335 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0302 - learning_rate: 0.0010
# Epoch 14/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0021 - masked_displaced_joint_mae: 0.0332 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0298 - learning_rate: 0.0010
# Epoch 15/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0021 - masked_displaced_joint_mae: 0.0330 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0301 - learning_rate: 0.0010
# Epoch 16/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020 - masked_displaced_joint_mae: 0.0327 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0298 - learning_rate: 0.0010
# Epoch 17/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020 - masked_displaced_joint_mae: 0.0325 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0295 - learning_rate: 0.0010
# Epoch 18/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0020 - masked_displaced_joint_mae: 0.0323 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0292 - learning_rate: 0.0010
# Epoch 19/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020 - masked_displaced_joint_mae: 0.0322 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0291 - learning_rate: 0.0010
# Epoch 20/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020 - masked_displaced_joint_mae: 0.0321 - val_loss: 0.0018 - val_masked_displaced_joint_mae: 0.0296 - learning_rate: 0.0010
# Epoch 21/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0320 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0292 - learning_rate: 0.0010
# Epoch 22/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0319 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0290 - learning_rate: 0.0010
# Epoch 23/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0316 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0288 - learning_rate: 0.0010
# Epoch 24/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0315 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0290 - learning_rate: 0.0010
# Epoch 25/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0314 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0289 - learning_rate: 0.0010
# Epoch 26/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0312 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0293 - learning_rate: 0.0010
# Epoch 27/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019 - masked_displaced_joint_mae: 0.0312 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0291 - learning_rate: 0.0010
# Epoch 28/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0018 - masked_displaced_joint_mae: 0.0311 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0287 - learning_rate: 0.0010
# Epoch 29/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0018 - masked_displaced_joint_mae: 0.0310 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0289 - learning_rate: 0.0010
# Epoch 30/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0018 - masked_displaced_joint_mae: 0.0309 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0292 - learning_rate: 0.0010
# Epoch 31/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0018 - masked_displaced_joint_mae: 0.0308 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0286 - learning_rate: 0.0010
# Epoch 32/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0018 - masked_displaced_joint_mae: 0.0308 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0288 - learning_rate: 0.0010
# Epoch 33/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0018 - masked_displaced_joint_mae: 0.0306 - val_loss: 0.0017 - val_masked_displaced_joint_mae: 0.0286 - learning_rate: 0.0010
# Epoch 34/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0016 - masked_displaced_joint_mae: 0.0291 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 35/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0016 - masked_displaced_joint_mae: 0.0287 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0269 - learning_rate: 5.0000e-04
# Epoch 36/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0016 - masked_displaced_joint_mae: 0.0287 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 37/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0016 - masked_displaced_joint_mae: 0.0286 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 38/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0016 - masked_displaced_joint_mae: 0.0285 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0270 - learning_rate: 5.0000e-04
# Epoch 39/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0016 - masked_displaced_joint_mae: 0.0285 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0269 - learning_rate: 5.0000e-04
# Epoch 40/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0283 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0268 - learning_rate: 5.0000e-04
# Epoch 41/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0283 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0266 - learning_rate: 5.0000e-04
# Epoch 42/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0283 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0267 - learning_rate: 5.0000e-04
# Epoch 43/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0282 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0269 - learning_rate: 5.0000e-04
# Epoch 44/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0281 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0268 - learning_rate: 5.0000e-04
# Epoch 45/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0281 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0267 - learning_rate: 5.0000e-04
# Epoch 46/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0281 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0269 - learning_rate: 5.0000e-04
# Epoch 47/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0281 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0267 - learning_rate: 5.0000e-04
# Epoch 48/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0280 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0267 - learning_rate: 5.0000e-04
# Epoch 49/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0015 - masked_displaced_joint_mae: 0.0279 - val_loss: 0.0015 - val_masked_displaced_joint_mae: 0.0269 - learning_rate: 5.0000e-04
# Epoch 50/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0272 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0259 - learning_rate: 2.5000e-04
# Epoch 51/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0270 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0259 - learning_rate: 2.5000e-04
# Epoch 52/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0269 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0257 - learning_rate: 2.5000e-04
# Epoch 53/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0269 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0259 - learning_rate: 2.5000e-04
# Epoch 54/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0268 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0258 - learning_rate: 2.5000e-04
# Epoch 55/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0268 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0259 - learning_rate: 2.5000e-04
# Epoch 56/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0268 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0257 - learning_rate: 2.5000e-04
# Epoch 57/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0267 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0259 - learning_rate: 2.5000e-04
# Epoch 58/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0267 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0256 - learning_rate: 2.5000e-04
# Epoch 59/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0267 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0257 - learning_rate: 2.5000e-04
# Epoch 60/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0267 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0258 - learning_rate: 2.5000e-04
# Epoch 61/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0266 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0257 - learning_rate: 2.5000e-04
# Epoch 62/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0266 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0256 - learning_rate: 2.5000e-04
# Epoch 63/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0266 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0256 - learning_rate: 2.5000e-04
# Epoch 64/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0266 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0258 - learning_rate: 2.5000e-04
# Epoch 65/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0014 - masked_displaced_joint_mae: 0.0265 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0257 - learning_rate: 2.5000e-04
# Epoch 66/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0262 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0253 - learning_rate: 1.2500e-04
# Epoch 67/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0260 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0253 - learning_rate: 1.2500e-04
# Epoch 68/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0260 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 69/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0260 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0253 - learning_rate: 1.2500e-04
# Epoch 70/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0260 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0253 - learning_rate: 1.2500e-04
# Epoch 71/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0260 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 72/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0260 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 73/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0259 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 74/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0259 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 75/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0259 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 76/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0259 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 77/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0259 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0251 - learning_rate: 1.2500e-04
# Epoch 78/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0259 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0253 - learning_rate: 1.2500e-04
# Epoch 79/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0258 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0251 - learning_rate: 1.2500e-04
# Epoch 80/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0258 - val_loss: 0.0014 - val_masked_displaced_joint_mae: 0.0251 - learning_rate: 1.2500e-04
# Epoch 81/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0256 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 82/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0256 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 83/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0256 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 84/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 85/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 86/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 87/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 88/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 89/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 6.2500e-05
# Epoch 90/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 6.2500e-05
# Epoch 91/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 92/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0249 - learning_rate: 6.2500e-05
# Epoch 93/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 6.2500e-05
# Epoch 94/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0254 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 6.2500e-05
# Epoch 95/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0013 - masked_displaced_joint_mae: 0.0255 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 6.2500e-05
# Epoch 96/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 3.1250e-05
# Epoch 97/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 3.1250e-05
# Epoch 98/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0248 - learning_rate: 3.1250e-05
# Epoch 99/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 100/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 101/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0254 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 102/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 103/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 104/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 105/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 106/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 107/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 108/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 109/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 110/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0253 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 111/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 112/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 113/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 114/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 115/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 116/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 117/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 118/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 119/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 120/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 121/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 122/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.5625e-05
# Epoch 123/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 124/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.5625e-05
# Epoch 125/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0247 - learning_rate: 1.5625e-05
# Epoch 126/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 127/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0252 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 128/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 129/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 130/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 131/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 132/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 133/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 134/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 135/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 136/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 137/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 138/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 139/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 140/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 7.8125e-06
# Epoch 141/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 142/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 143/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 144/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 145/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 146/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 147/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 148/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 149/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 150/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 151/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 152/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 153/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 154/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 155/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 3.9063e-06
# Epoch 156/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 157/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 158/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 159/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 160/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 161/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 162/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 163/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 164/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 165/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 166/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 167/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 168/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 169/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 170/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.9531e-06
# Epoch 171/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 172/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 173/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 174/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 175/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 176/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 177/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 178/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 179/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 180/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 181/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 182/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 183/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 184/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 185/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 186/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 187/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 188/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 189/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 190/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 191/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 192/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 193/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 194/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 195/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 196/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 197/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 198/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 199/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 200/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 201/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 202/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 203/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0250 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 204/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 205/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 206/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06
# Epoch 207/250
# 590/590 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0012 - masked_displaced_joint_mae: 0.0251 - val_loss: 0.0013 - val_masked_displaced_joint_mae: 0.0246 - learning_rate: 1.0000e-06

# %%
def r2_score_np(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    y_true = np.asarray(y_true, dtype=np.float32)
    y_pred = np.asarray(y_pred, dtype=np.float32)
    ss_res = float(np.sum((y_true - y_pred) ** 2))
    ss_tot = float(np.sum((y_true - np.mean(y_true, axis=0, keepdims=True)) ** 2))
    return 1.0 - ss_res / (ss_tot + 1e-12)

y_pred = model.predict(X_test, batch_size=1024)
mae = float(np.mean(np.abs(y_test - y_pred)))
r2 = r2_score_np(y_test, y_pred)

print(f"Test MAE (mean over all dims): {mae:.6f}")
print(f"Test R2 (global): {r2:.6f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test MAE (mean over all dims): 0.013311
# Test R2 (global): 0.259497

# %%
# --------
# Training curves
# --------

plt.figure(figsize=(7, 4))
plt.plot(history.history.get("loss", []), label="train")
plt.plot(history.history.get("val_loss", []), label="val")
plt.title("Loss (masked Huber, displaced joints)")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(7, 4))
_mae_key = "masked_displaced_joint_mae" if "masked_displaced_joint_mae" in history.history else "mae"
plt.plot(history.history.get(_mae_key, []), label="train")
plt.plot(history.history.get(f"val_{_mae_key}", []), label="val")
plt.title("MAE (displaced joints only)")
plt.xlabel("epoch")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --------
# Prediction visualizations + qualitative skeleton plots
# --------

n_landmarks = int(metadata["n_landmarks"])
n_coords = int(metadata["n_coords"])
pose_dim = int(metadata["X_pose_flat_dim"])

# Landmark order:
# 0 left_shoulder, 1 right_shoulder, 2 left_elbow, 3 right_elbow,
# 4 left_wrist, 5 right_wrist, 6 left_hip, 7 right_hip,
# 8 left_knee, 9 right_knee, 10 left_ankle, 11 right_ankle
edges = [
    (0, 1),
    (6, 7),
    (0, 2), (2, 4),
    (1, 3), (3, 5),
    (0, 6), (1, 7),
    (6, 8), (8, 10),
    (7, 9), (9, 11),
]

def plot_skeleton_with_arrows(pose_xy, disp_true_xy, disp_pred_xy, title=""):
    from matplotlib.lines import Line2D

    pose_xy = np.asarray(pose_xy)
    dt = np.asarray(disp_true_xy)
    dp = np.asarray(disp_pred_xy)

    fig, ax = plt.subplots(figsize=(6, 6))

    for i, j in edges:
        ax.plot([pose_xy[i, 0], pose_xy[j, 0]], [pose_xy[i, 1], pose_xy[j, 1]], "k-", alpha=0.35, zorder=1)
    ax.scatter(pose_xy[:, 0], pose_xy[:, 1], s=25, zorder=2)

    # Draw BOTH: true first, pred on top.
    ax.quiver(
        pose_xy[:, 0],
        pose_xy[:, 1],
        dt[:, 0],
        dt[:, 1],
        angles="xy",
        scale_units="xy",
        scale=1.0,
        color="tab:green",
        alpha=0.85,
        width=0.004,
        zorder=3,
    )
    ax.quiver(
        pose_xy[:, 0],
        pose_xy[:, 1],
        dp[:, 0],
        dp[:, 1],
        angles="xy",
        scale_units="xy",
        scale=1.0,
        color="tab:red",
        alpha=0.85,
        width=0.004,
        zorder=4,
    )

    # Legend via proxy artists (quiver labels can be flaky).
    proxies = [
        Line2D([0], [0], color="tab:green", lw=2, label="true displacement"),
        Line2D([0], [0], color="tab:red", lw=2, label="pred displacement"),
    ]
    ax.legend(handles=proxies, loc="upper right")

    # Numeric key
    true_ma = float(np.mean(np.abs(dt)))
    pred_ma = float(np.mean(np.abs(dp)))
    err_ma = float(np.mean(np.abs(dt - dp)))
    ax.text(
        0.02,
        0.02,
        f"mean|true|={true_ma:.4f}\nmean|pred|={pred_ma:.4f}\nmean|err|={err_ma:.4f}",
        transform=ax.transAxes,
        fontsize=10,
        va="bottom",
        ha="left",
        bbox=dict(boxstyle="round", facecolor="white", alpha=0.75, edgecolor="none"),
        zorder=10,
    )

    ax.invert_yaxis()  # image-like coordinates
    ax.set_title(title)
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    plt.show()

# Global error histogram
err = (y_test - y_pred)
err_norm = np.linalg.norm(err, axis=1)
plt.figure(figsize=(7, 4))
plt.hist(err_norm, bins=80)
plt.title("Test error magnitude (L2) histogram")
plt.xlabel("||y_true - y_pred||")
plt.ylabel("count")
plt.tight_layout()
plt.show()

# Scatter: true vs pred norms
plt.figure(figsize=(5, 5))
plt.scatter(np.linalg.norm(y_test, axis=1), np.linalg.norm(y_pred, axis=1), s=3, alpha=0.25)
plt.title("||y||: true vs predicted")
plt.xlabel("||y_true||")
plt.ylabel("||y_pred||")
plt.tight_layout()
plt.show()

# Per-joint MAE (2D)
err_nodes = err.reshape((-1, n_landmarks, n_coords))
per_joint_mae = np.mean(np.abs(err_nodes), axis=(0, 2))
plt.figure(figsize=(9, 3))
plt.bar(np.arange(n_landmarks), per_joint_mae)
plt.title("Per-joint MAE (averaged over x/y)")
plt.xlabel("joint index")
plt.ylabel("MAE")
plt.tight_layout()
plt.show()

# Qualitative samples
rng = np.random.default_rng(0)
for k in rng.choice(np.arange(X_test.shape[0]), size=3, replace=False):
    pose_xy = X_test[k, :pose_dim].reshape((n_landmarks, n_coords))[:, :2]
    y_true_xy = y_test[k].reshape((n_landmarks, n_coords))[:, :2]
    y_pred_xy = y_pred[k].reshape((n_landmarks, n_coords))[:, :2]
    plot_skeleton_with_arrows(pose_xy, y_true_xy, y_pred_xy, title=f"sample {int(k)}")

# %%
out_dir = Path("./saved_models")
out_dir.mkdir(parents=True, exist_ok=True)
save_path = out_dir / "mlp_single_frame_displacement.keras"
model.save(save_path)
print(f"Saved to: {save_path}")
# Out:
# Saved to: saved_models/mlp_single_frame_displacement.keras
