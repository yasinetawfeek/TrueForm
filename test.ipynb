# %%
import numpy as np
import pandas as pd

npz_path = "Data/output_displacement_single_frame_new/bicep_curls/training_data_displacement_per_frame.npz"
data = np.load(npz_path, allow_pickle=True)

data.files  # see available arrays/keys
# Out:
# ['X',
#  'y',
#  'y_class',
#  'y_class_onehot',
#  'y_class_raw',
#  'class_names',
#  'n_landmarks',
#  'n_coords',
#  'sequence_length']

# %%
X = data["X"]          # (N, T*12*3 + class_dim)
print(X.shape)
y = data["y"]          # (N, T*12*3)
y_class = data["y_class"]
class_names = data["class_names"]

dfX = pd.DataFrame(X)
dfy = pd.DataFrame(y)

display(dfX.head())
dfy
# Out:
# (42021, 25)
#          0         1         2         3         4         5         6   \
# 0  0.513579  0.210269  0.416907  0.211962  0.514400  0.345949  0.409477
# 1  0.454920  0.178195  0.416770  0.211956  0.514485  0.347260  0.410158
# 2  0.513660  0.210491  0.416643  0.211960  0.514549  0.347775  0.323389
# 3  0.513686  0.210723  0.416571  0.211992  0.567267  0.397090  0.410826
# 4  0.567311  0.292535  0.416442  0.212027  0.514727  0.348269  0.411078
#
#          7         8         9   ...        15        16        17        18  \
# 0  0.353025  0.535368  0.445047  ...  0.486656  0.488499  0.717178  0.403348
# 1  0.353266  0.535384  0.445035  ...  0.486892  0.520102  0.696695  0.403272
# 2  0.265740  0.535396  0.444990  ...  0.486986  0.520342  0.698317  0.403304
# 3  0.353436  0.535615  0.445842  ...  0.486965  0.520579  0.699001  0.403284
# 4  0.353513  0.535785  0.445778  ...  0.486967  0.520752  0.700046  0.403205
#
# ...
